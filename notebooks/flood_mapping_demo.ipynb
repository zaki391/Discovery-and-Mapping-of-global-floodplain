# %% [markdown]
# # Flood Mapping Demo
# This notebook demonstrates feature engineering, training, and evaluation for flood mapping.

# %%
import numpy as np
from flood_mapping.evaluation import classification_metrics

y_true = np.array([1, 0, 1, 1, 0, 0, 1, 0])
y_pred = np.array([1, 0, 1, 0, 0, 0, 1, 1])
classification_metrics(y_true, y_pred)
